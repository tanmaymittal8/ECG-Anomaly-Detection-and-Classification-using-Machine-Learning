# %%
import numpy as np
import matplotlib.pyplot as plt

with open('results11.npy', 'rb') as f:
    X_data = np.load(f)
    Y_data = np.load(f) 

print(X_data.shape)
plt.figure(figsize=(30,6))
plt.plot(X_data, Y_data)
# Out:
# (256,)

# %%
X_data = X_data[0:187]
Y_data = Y_data[0:187]
Y_data = Y_data/ (np.max(Y_data))

result = np.array([X_data, Y_data])



plt.plot(Y_data)

# %%
with open('results1.npy', 'rb') as f:
    X_data = np.load(f)
    Y_data = np.load(f) 

print(X_data.shape)
plt.plot(X_data, Y_data)
# Out:
# (253,)

# %%
with open('results2.npy', 'rb') as f:
    X_data = np.load(f)
    Y_data = np.load(f) 

print(X_data.shape)
plt.plot(X_data, Y_data)
# Out:
# (252,)

# %%
with open('results3.npy', 'rb') as f:
    X_data = np.load(f)
    Y_data = np.load(f) 

print(X_data.shape)
plt.plot(X_data, Y_data)
# Out:
# (248,)

# %%
with open('results4.npy', 'rb') as f:
    X_data = np.load(f)
    Y_data = np.load(f) 

print(X_data.shape)
plt.plot(X_data, Y_data)
# Out:
# (245,)

# %%
with open('results5.npy', 'rb') as f:
    X_data = np.load(f)
    Y_data = np.load(f) 

print(X_data.shape)
plt.plot(X_data, Y_data)
# Out:
# (263,)

# %%
with open('results6.npy', 'rb') as f:
    X_data = np.load(f)
    Y_data = np.load(f) 

print(X_data.shape)
plt.plot(X_data, Y_data)
# Out:
# (257,)

# %%
with open('results7.npy', 'rb') as f:
    X_data = np.load(f)
    Y_data = np.load(f) 

print(X_data.shape)
plt.plot(X_data, Y_data)
# Out:
# (263,)

# %%
with open('results8.npy', 'rb') as f:
    X_data = np.load(f)
    Y_data = np.load(f) 

print(X_data.shape)
plt.plot(X_data, Y_data)
# Out:
# (255,)

# %%
with open('results9.npy', 'rb') as f:
    X_data = np.load(f)
    Y_data = np.load(f) 

print(X_data.shape)
plt.plot(X_data, Y_data)
# Out:
# (256,)

# %%
with open('results10.npy', 'rb') as f:
    X_data = np.load(f)
    Y_data = np.load(f) 

print(X_data.shape)
plt.figure(figsize=(30,6))
plt.plot(X_data, Y_data)
# Out:
# (257,)
